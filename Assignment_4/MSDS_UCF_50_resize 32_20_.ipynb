# %%
# !pip install pafy
# !pip install youtube-dl
# Out:
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Installing collected packages: pafy
# Successfully installed pafy-0.5.5
# Collecting youtube-dl
#   Downloading youtube_dl-2021.6.6-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 5.2 MB/s
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.6.6

# %%
import os
import cv2
import math
import pafy
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from moviepy.editor import *
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

import os
import glob
import keras
import gc
# from tensorflow.keras.utils import Sequence
# from tf.keras_video import VideoFrameGenerator
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib as mpl  # EA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score
import concurrent.futures 
from time import sleep
import pandas as pd
import time

# %%
def print_validation_report(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(20,20))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
def plot_confusion_matrix_labeled(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    # define classes 
    classes = CLASSES_LIST
    temp_df = pd.DataFrame(data=mtx,columns=classes)
    temp_df.index = classes
    fig, ax = plt.subplots(figsize=(20,20))
    sns.heatmap(temp_df, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
def print_validation_report_labeled(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions, target_names= CLASSES_LIST))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions))))

# %%
#!pip install keras-video-generators

# %%
seed_constant = 23
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **step 1 load data**

# %%
# !rm '/content/UCF50.rar'

# %%
# !rm -r -f '/content/UCF50'

# %%
# !wget -nc --no-check-certificate https://www.crcv.ucf.edu/data/UCF50.rar
# !unrar x UCF50.rar -inul -y
# Out:
# --2021-12-06 01:39:01--  https://www.crcv.ucf.edu/data/UCF50.rar
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 3233554570 (3.0G) [application/rar]
# Saving to: ‘UCF50.rar’
#
# UCF50.rar            25%[====>               ] 778.86M  79.4MB/s    in 10s
#
# 2021-12-06 01:39:12 (77.3 MB/s) - Connection closed at byte 816692766. Retrying.
#
# --2021-12-06 01:39:13--  (try: 2)  https://www.crcv.ucf.edu/data/UCF50.rar
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3233554570 (3.0G), 2416861804 (2.2G) remaining [application/rar]
# Saving to: ‘UCF50.rar’
#
# UCF50.rar            52%[+++++====>          ]   1.57G  78.7MB/s    in 11s
#
# 2021-12-06 01:39:24 (76.7 MB/s) - Connection closed at byte 1690270713. Retrying.
#
# --2021-12-06 01:39:26--  (try: 3)  https://www.crcv.ucf.edu/data/UCF50.rar
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3233554570 (3.0G), 1543283857 (1.4G) remaining [application/rar]
# Saving to: ‘UCF50.rar’
#
# UCF50.rar            79%[++++++++++====>     ]   2.39G  77.8MB/s    in 11s
#
# 2021-12-06 01:39:37 (77.1 MB/s) - Connection closed at byte 2568944083. Retrying.
#
# --2021-12-06 01:39:40--  (try: 4)  https://www.crcv.ucf.edu/data/UCF50.rar
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 3233554570 (3.0G), 664610487 (634M) remaining [application/rar]
# Saving to: ‘UCF50.rar’
#
# UCF50.rar           100%[+++++++++++++++====>]   3.01G  78.2MB/s    in 8.3s
#
# 2021-12-06 01:39:49 (76.6 MB/s) - ‘UCF50.rar’ saved [3233554570/3233554570]

# %%
# !mv "/content/UCF50"    "/content/gdrive/MyDrive/UCF50"

# %%
# !cp -r "/content/gdrive/MyDrive/UCF50" "/content/"

# %%
# !rsync -a -f"+ */" -f"- *" "/content/gdrive/MyDrive/UCF50" "/content/"

# %% [markdown]
# **Step 2: Visualize the Data with its Labels**

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('UCF50')

# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 20)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'UCF50/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'UCF50/{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
datasize = {}
for name in os.listdir('UCF50'):
    datasize[name] = len(os.listdir('UCF50/{}'.format(name)))

# %%
import subprocess

def get_length(filename):
    result = subprocess.run(["ffprobe", "-v", "error", "-show_entries",
                             "format=duration", "-of",
                             "default=noprint_wrappers=1:nokey=1", filename],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT)
    return float(result.stdout)

# %%
video_size =[]
for filename in os.listdir("UCF50"):
  counter = 1
  for name in os.listdir('UCF50/{}'.format(filename)):
    vidpath = os.path.join("./UCF50", filename,name)
    cap = cv2.VideoCapture(vidpath)
    #cap = cv2.VideoCapture("./video.mp4")
    fps = cap.get(cv2.CAP_PROP_FPS)      # OpenCV2 version 2 used "CV_CAP_PROP_FPS"
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = frame_count/fps
    width  = cap.get(cv2.CAP_PROP_FRAME_WIDTH)   # float `width`
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)  # float `height
    video_size.append([filename,counter,duration,frame_count, fps, width,height])
    counter +=1
    
    #print(vidpath)
    #vidcap = cv2.VideoCapture(vidpath)
    #print(vidcap.get(cv2.CAP_PROP_POS_MSEC))

# %%
import pandas as pd
vid_des = pd.DataFrame(video_size, columns=['Action','#','Duration s',' Fames count','FPS', 'width','height' ])

# %%
v_desc = vid_des.groupby("Action").apply(lambda x: x.reset_index())

# %%
v_desc[['Duration s']].unstack().plot(kind='bar', legend = False, figsize =(20,15), rot=  70,  ylabel = "Time in Seconds")

# %%
v_desc[[' Fames count']].unstack().plot(kind='bar', legend = False, figsize =(20,15), rot=  70,  ylabel = "Number of frames")

# %%
v_desc[['FPS']].unstack().plot(kind='bar', legend = False, figsize =(20,15), rot=  70,  ylabel = "Number of frames")

# %%
v_desc[['width']].unstack().plot(kind='bar', legend = False, figsize =(20,15), rot=  70,  ylabel = "Number of frames")

# %%
v_desc[['height']].unstack().plot(kind='bar', legend = False, figsize =(20,15), rot=  70,  ylabel = "Number of frames")

# %% [markdown]
# **step 2 preprocess data**

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH =32, 32

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 20

# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "UCF50"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.


CLASSES_LIST = sorted(list(os.listdir('/content/gdrive/MyDrive/UCF50')))

# %% [markdown]
# **Extract, Resize and Normalize Frames**

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list =[] #np.array([])
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
    gc.collect()
    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 
        gc.collect()

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
        
        gc.collect()
    # Release the VideoCapture object. 
    video_reader.release()
    gc.collect()
    # Return the frames list.
    return frames_list

# %%
# uses # multthreading using process pool
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    feature = []
    label = []
    video_files_paths = []
  
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        gc.collect()
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        video_file_path = []
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path.append(os.path.join(DATASET_DIR, class_name, file_name))

            # Extract the frames of the video file.
        with concurrent.futures.ProcessPoolExecutor() as executor:
          result = executor.map(frames_extraction, video_file_path)

        # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
        # So ignore the vides having frames less than the SEQUENCE_LENGTH.
        for frames in result:
          if len(frames) == SEQUENCE_LENGTH:
        
            # # Append the data to their repective lists.
            feature.append(frames)
            label.append(class_index)
            #video_files_paths.append(video_file_path)
            gc.collect()

            

    # Converting the list to numpy arrays
    features = np.asarray(feature)
    del(feature)
    gc.collect()
    labels = np.array(label) 
    del(label) 
    gc.collect()
    # Return the frames, class index, and video file path.
    return features, labels #, video_files_paths

# %% [markdown]
# **Dataset Creation**

# %%
# def create_dataset():
#     '''
#     This function will extract the data of the selected classes and create the required dataset.
#     Returns:
#         features:          A list containing the extracted frames of the videos.
#         labels:            A list containing the indexes of the classes associated with the videos.
#         video_files_paths: A list containing the paths of the videos in the disk.
#     '''

#     # Declared Empty Lists to store the features, labels and video file path values.
#     features = []
#     labels = []
#     video_files_paths = []
  
#     # Iterating through all the classes mentioned in the classes list
#     for class_index, class_name in enumerate(CLASSES_LIST):
#         gc.collect()
#         # Display the name of the class whose data is being extracted.
#         print(f'Extracting Data of Class: {class_name}')
        
#         # Get the list of video files present in the specific class name directory.
#         files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
#         # Iterate through all the files present in the files list.
#         video_file_path = []
#         for file_name in files_list:
            
#             # Get the complete video path.
#             video_file_path.append(os.path.join(DATASET_DIR, class_name, file_name))

#             # Extract the frames of the video file.
#         with concurrent.futures.ThreadPoolExecutor() as executor:
#           result = executor.map(frames_extraction, video_file_path)

#         # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
#         # So ignore the vides having frames less than the SEQUENCE_LENGTH.
#         for frames in result:
#           if len(frames) == SEQUENCE_LENGTH:
        
#             # Append the data to their repective lists.
#             features.append(frames)
#             labels.append(class_index)
#             #video_files_paths.append(video_file_path)
#             gc.collect()

#     # Converting the list to numpy arrays
#     features = np.asarray(features)
#     labels = np.array(labels)  
#     gc.collect()
#     # Return the frames, class index, and video file path.
#     return features, labels #, video_files_paths

# %% [markdown]
# **create_dataset method which returns features and labels.**

# %%
nat
# Out:
# []

# %%
NUM_THREADS=8
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)
features, labels = create_dataset()
# Out:
# Extracting Data of Class: BaseballPitch
# Extracting Data of Class: Basketball
# Extracting Data of Class: BenchPress
# Extracting Data of Class: Biking
# Extracting Data of Class: Billiards
# Extracting Data of Class: BreastStroke
# Extracting Data of Class: CleanAndJerk
# Extracting Data of Class: Diving
# Extracting Data of Class: Drumming
# Extracting Data of Class: Fencing
# Extracting Data of Class: GolfSwing
# Extracting Data of Class: HighJump
# Extracting Data of Class: HorseRace
# Extracting Data of Class: HorseRiding
# Extracting Data of Class: HulaHoop
# Extracting Data of Class: JavelinThrow
# Extracting Data of Class: JugglingBalls
# Extracting Data of Class: JumpRope
# Extracting Data of Class: JumpingJack
# Extracting Data of Class: Kayaking
# Extracting Data of Class: Lunges
# Extracting Data of Class: MilitaryParade
# Extracting Data of Class: Mixing
# Extracting Data of Class: Nunchucks
# Extracting Data of Class: PizzaTossing
# Extracting Data of Class: PlayingGuitar
# Extracting Data of Class: PlayingPiano
# Extracting Data of Class: PlayingTabla
# Extracting Data of Class: PlayingViolin
# Extracting Data of Class: PoleVault
# Extracting Data of Class: PommelHorse
# Extracting Data of Class: PullUps
# Extracting Data of Class: Punch
# Extracting Data of Class: PushUps
# Extracting Data of Class: RockClimbingIndoor
# Extracting Data of Class: RopeClimbing

# %%
features.shape
# Out:
# (6681, 20, 32, 32, 3)

# %%
# f, l, v =features.copy(), labels.copy(), video_files_paths.copy()

# %%
# !cat /proc/cpuinfo

# %%
l = []

# %%
# type(video_files_paths)

# %%
# np.save("/content/gdrive/MyDrive/features_32_19", features,allow_pickle=True)

# %%
# np.save("/content/gdrive/MyDrive/labels_32_10", labels ,allow_pickle=True)

# %%
Class_np = np.array(CLASSES_LIST)

# %%
np.save("/content/gdrive/MyDrive/Class_np", Class_np ,allow_pickle=True)

# %%
# np.save("video_files_paths", video_files_paths,allow_pickle=True)

# %%
# !cp -r "/content/features.npy" "/content/gdrive/MyDrive/features"

# %%
# !cp -r "/content/labels.npy" "/content/gdrive/MyDrive/labels"

# %%
# !cp -r "/content/video_files_paths" "/content/gdrive/MyDrive/video_files_paths"
# Out:
# cp: cannot stat '/content/video_files_paths': No such file or directory

# %%
# !cp -r "/content/gdrive/MyDrive/features" "/content/"

# %%
# !cp -r "/content/gdrive/MyDrive/labels"  "/content/"

# %%
labels = np.load("/content/gdrive/MyDrive/labels_32_10.npy")

# %%
features = np.load("/content/gdrive/MyDrive/features_32_19.npy")

# %%
# video_files_paths = np.load("/content/gdrive/MyDrive/video_files_paths")

# %%
gc.collect()
# Out:
# 262

# %%
# !rm -r -f '/content/video_files_paths.npy'

# %% [markdown]
#  convert class labels to one hot encoded vectors

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels, num_classes=50)

# %% [markdown]
#  Split the Data into Train and Test Sets

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)

# %%
del(features)

# %%
gc.collect()
# Out:
# 203

# %% [markdown]
# **Step 5: Construct the Model**

# %%
NUM_THREADS=8
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''

    # We will use a Sequential model for model construction
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    #model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(Flatten()) 
    
    model.add(Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %%
import datetime
import time

# %% [markdown]
# Model structure

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message. 
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 20, 30, 30, 4)     1024
#
#  max_pooling3d (MaxPooling3D  (None, 20, 15, 15, 4)    0
#  )
#
#  time_distributed (TimeDistr  (None, 20, 15, 15, 4)    0
#  ibuted)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 20, 13, 13, 8)     3488
#
#  max_pooling3d_1 (MaxPooling  (None, 20, 7, 7, 8)      0
#  3D)
#
#  time_distributed_1 (TimeDis  (None, 20, 7, 7, 8)      0
#  tributed)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 20, 5, 5, 14)      11144
#
#  max_pooling3d_2 (MaxPooling  (None, 20, 3, 3, 14)     0
#  3D)
#
#  time_distributed_2 (TimeDis  (None, 20, 3, 3, 14)     0
#  tributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 20, 1, 1, 16)      17344
#
#  max_pooling3d_3 (MaxPooling  (None, 20, 1, 1, 16)     0
#  3D)
#
#  flatten (Flatten)           (None, 320)               0
#
#  dense (Dense)               (None, 50)                16050
#
# =================================================================
# Total params: 49,050
# Trainable params: 49,050
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %%
# Plot the structure of the contructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
NUM_THREADS=8
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# %% [markdown]
# train model

# %%
# %%time
NUM_THREADS=8
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)

# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 4,
                                                     shuffle = True, validation_split = 0.2, 
                                                     callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 1002/1002 [==============================] - 249s 240ms/step - loss: 3.5432 - accuracy: 0.0948 - val_loss: 3.1232 - val_accuracy: 0.1836
# Epoch 2/50
# 1002/1002 [==============================] - 242s 242ms/step - loss: 2.9545 - accuracy: 0.2068 - val_loss: 2.9380 - val_accuracy: 0.2086
# Epoch 3/50
# 1002/1002 [==============================] - 244s 244ms/step - loss: 2.5347 - accuracy: 0.2939 - val_loss: 2.5449 - val_accuracy: 0.2994
# Epoch 4/50
# 1002/1002 [==============================] - 245s 245ms/step - loss: 2.2075 - accuracy: 0.3730 - val_loss: 2.3178 - val_accuracy: 0.3553
# Epoch 5/50
# 1002/1002 [==============================] - 246s 246ms/step - loss: 1.9868 - accuracy: 0.4279 - val_loss: 2.1639 - val_accuracy: 0.4002
# Epoch 6/50
# 1002/1002 [==============================] - 246s 246ms/step - loss: 1.7807 - accuracy: 0.4848 - val_loss: 2.1002 - val_accuracy: 0.4192
# Epoch 7/50
# 1002/1002 [==============================] - 248s 247ms/step - loss: 1.6401 - accuracy: 0.5264 - val_loss: 1.9776 - val_accuracy: 0.4581
# Epoch 8/50
# 1002/1002 [==============================] - 249s 249ms/step - loss: 1.4993 - accuracy: 0.5659 - val_loss: 1.9895 - val_accuracy: 0.4731
# Epoch 9/50
# 1002/1002 [==============================] - 251s 250ms/step - loss: 1.3736 - accuracy: 0.5951 - val_loss: 2.0263 - val_accuracy: 0.4621
# Epoch 10/50
# 1002/1002 [==============================] - 250s 250ms/step - loss: 1.2839 - accuracy: 0.6133 - val_loss: 1.8504 - val_accuracy: 0.5190
# Epoch 11/50
# 1002/1002 [==============================] - 251s 250ms/step - loss: 1.1860 - accuracy: 0.6492 - val_loss: 1.9985 - val_accuracy: 0.4960
# Epoch 12/50
# 1002/1002 [==============================] - 250s 250ms/step - loss: 1.1151 - accuracy: 0.6729 - val_loss: 1.8639 - val_accuracy: 0.5250
# Epoch 13/50
# 1002/1002 [==============================] - 250s 250ms/step - loss: 1.0348 - accuracy: 0.6856 - val_loss: 1.9377 - val_accuracy: 0.5240
# Epoch 14/50
# 1002/1002 [==============================] - 250s 250ms/step - loss: 0.9986 - accuracy: 0.6979 - val_loss: 1.9434 - val_accuracy: 0.5269
# Epoch 15/50
# 1002/1002 [==============================] - 250s 249ms/step - loss: 0.9284 - accuracy: 0.7158 - val_loss: 1.7950 - val_accuracy: 0.5559
# Epoch 16/50
# 1002/1002 [==============================] - 252s 252ms/step - loss: 0.8966 - accuracy: 0.7263 - val_loss: 1.8754 - val_accuracy: 0.5489
# Epoch 17/50
# 1002/1002 [==============================] - 253s 253ms/step - loss: 0.8264 - accuracy: 0.7488 - val_loss: 1.9540 - val_accuracy: 0.5529
# Epoch 18/50
# 1002/1002 [==============================] - 253s 253ms/step - loss: 0.7805 - accuracy: 0.7642 - val_loss: 2.0118 - val_accuracy: 0.5529
# Epoch 19/50
# 1002/1002 [==============================] - 254s 254ms/step - loss: 0.7589 - accuracy: 0.7657 - val_loss: 1.8269 - val_accuracy: 0.5828
# Epoch 20/50
# 1002/1002 [==============================] - 254s 253ms/step - loss: 0.7359 - accuracy: 0.7725 - val_loss: 1.7998 - val_accuracy: 0.5838
# Epoch 21/50
# 1002/1002 [==============================] - 254s 254ms/step - loss: 0.6922 - accuracy: 0.7812 - val_loss: 1.8717 - val_accuracy: 0.5838
# Epoch 22/50
# 1002/1002 [==============================] - 255s 254ms/step - loss: 0.6374 - accuracy: 0.8054 - val_loss: 1.7962 - val_accuracy: 0.5838
# Epoch 23/50
# 1002/1002 [==============================] - 253s 252ms/step - loss: 0.6297 - accuracy: 0.8026 - val_loss: 1.8613 - val_accuracy: 0.5699
# Epoch 24/50
# 1002/1002 [==============================] - 252s 252ms/step - loss: 0.5878 - accuracy: 0.8089 - val_loss: 2.0508 - val_accuracy: 0.5529
# Epoch 25/50
# 1002/1002 [==============================] - 254s 254ms/step - loss: 0.5991 - accuracy: 0.8074 - val_loss: 2.0268 - val_accuracy: 0.5639
# CPU times: user 5h 24min 49s, sys: 45min 39s, total: 6h 10min 28s
# Wall time: 1h 44min 17s

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
# Visualize the training and validation loss metrices.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
gc.collect()

# %% [markdown]
# save model

# %%
# Creating a useful name for our model, incase you're saving multiple models (OPTIONAL)
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history
model_name = f'Model___Date_Time_{current_date_time_string}___Loss_
{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Saving your Model
model.save(model_name)

# %%
convlstm_model.evaluate(features_test,labels_test )
# Out:
# 53/53 [==============================] - 14s 263ms/step - loss: 1.9031 - accuracy: 0.5464
# [1.9030911922454834, 0.5463793873786926]

# %% [markdown]
# plot model accuracy and loss

# %%
plot_metric('loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric('accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.1: Construct the Model</font>**
#
# To implement our LRCN architecture, we will use time-distributed **`Conv2D`** layers which will be followed by **`MaxPooling2D`** and **`Dropout`** layers. The feature extracted from the **`Conv2D`** layers will be then flattened using the  **`Flatten`** layer and will be fed to a **`LSTM`** layer. The **`Dense`** layer with softmax activation will then use the output from the **`LSTM`** layer to predict the action being performed.

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(8, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((1, 1))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((1, 1))))
    #model.add(TimeDistributed(Dropout(0.25)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(32)),

    model.add(Dense(256))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %% [markdown]
# Now we will utilize the function **`create_LRCN_model()`** created above to construct the required `LRCN` model.

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_47 (TimeDi  (None, 20, 32, 32, 8)    224
#  stributed)
#
#  time_distributed_48 (TimeDi  (None, 20, 8, 8, 8)      0
#  stributed)
#
#  time_distributed_49 (TimeDi  (None, 20, 8, 8, 8)      0
#  stributed)
#
#  time_distributed_50 (TimeDi  (None, 20, 8, 8, 16)     1168
#  stributed)
#
#  time_distributed_51 (TimeDi  (None, 20, 2, 2, 16)     0
#  stributed)
#
#  time_distributed_52 (TimeDi  (None, 20, 2, 2, 16)     0
#  stributed)
#
#  time_distributed_53 (TimeDi  (None, 20, 2, 2, 32)     4640
#  stributed)
#
#  time_distributed_54 (TimeDi  (None, 20, 2, 2, 32)     0
#  stributed)
#
#  time_distributed_55 (TimeDi  (None, 20, 2, 2, 32)     0
#  stributed)
#
#  time_distributed_56 (TimeDi  (None, 20, 2, 2, 32)     9248
#  stributed)
#
#  time_distributed_57 (TimeDi  (None, 20, 2, 2, 32)     0
#  stributed)
#
#  time_distributed_58 (TimeDi  (None, 20, 128)          0
#  stributed)
#
#  lstm (LSTM)                 (None, 32)                20608
#
#  dense_1 (Dense)             (None, 50)                1650
#
# =================================================================
# Total params: 37,538
# Trainable params: 37,538
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Check Model’s Structure:</font>**
#
# Now we will use the **`plot_model()`** function to check the structure of the constructed `LRCN` model. As we had checked for the previous model.

# %%
# Plot the structure of the contructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.2: Compile & Train the Model</font>**
#
#
# After checking the structure, we will compile and start training the model.

# %%
# %%time
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 1002/1002 [==============================] - 25s 23ms/step - loss: 3.7150 - accuracy: 0.0609 - val_loss: 3.4347 - val_accuracy: 0.0958
# Epoch 2/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 3.3856 - accuracy: 0.1038 - val_loss: 3.3609 - val_accuracy: 0.1277
# Epoch 3/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 3.1854 - accuracy: 0.1554 - val_loss: 3.1982 - val_accuracy: 0.1567
# Epoch 4/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 3.0945 - accuracy: 0.1724 - val_loss: 3.1619 - val_accuracy: 0.1617
# Epoch 5/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 2.9830 - accuracy: 0.2026 - val_loss: 3.0525 - val_accuracy: 0.1667
# Epoch 6/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.8698 - accuracy: 0.2161 - val_loss: 2.8843 - val_accuracy: 0.2365
# Epoch 7/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.7998 - accuracy: 0.2368 - val_loss: 2.8739 - val_accuracy: 0.2275
# Epoch 8/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.7222 - accuracy: 0.2552 - val_loss: 2.7913 - val_accuracy: 0.2545
# Epoch 9/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.6570 - accuracy: 0.2622 - val_loss: 2.7704 - val_accuracy: 0.2625
# Epoch 10/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.5851 - accuracy: 0.2854 - val_loss: 2.6855 - val_accuracy: 0.2665
# Epoch 11/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.5097 - accuracy: 0.3139 - val_loss: 2.5957 - val_accuracy: 0.2864
# Epoch 12/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.4423 - accuracy: 0.3196 - val_loss: 2.5685 - val_accuracy: 0.3004
# Epoch 13/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.3918 - accuracy: 0.3393 - val_loss: 2.5310 - val_accuracy: 0.2944
# Epoch 14/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.3286 - accuracy: 0.3523 - val_loss: 2.5526 - val_accuracy: 0.2894
# Epoch 15/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.2657 - accuracy: 0.3723 - val_loss: 2.5019 - val_accuracy: 0.3034
# Epoch 16/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 2.1959 - accuracy: 0.3815 - val_loss: 2.5059 - val_accuracy: 0.3064
# Epoch 17/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.1586 - accuracy: 0.4007 - val_loss: 2.4586 - val_accuracy: 0.3283
# Epoch 18/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 2.0989 - accuracy: 0.4169 - val_loss: 2.4049 - val_accuracy: 0.3463
# Epoch 19/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 2.0201 - accuracy: 0.4306 - val_loss: 2.3420 - val_accuracy: 0.3613
# Epoch 20/70
# 1002/1002 [==============================] - 23s 22ms/step - loss: 1.9891 - accuracy: 0.4411 - val_loss: 2.4041 - val_accuracy: 0.3413
# Epoch 21/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.9317 - accuracy: 0.4496 - val_loss: 2.3670 - val_accuracy: 0.3713
# Epoch 22/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.8625 - accuracy: 0.4703 - val_loss: 2.3508 - val_accuracy: 0.3663
# Epoch 23/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.8227 - accuracy: 0.4875 - val_loss: 2.2454 - val_accuracy: 0.3922
# Epoch 24/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.7872 - accuracy: 0.4960 - val_loss: 2.1918 - val_accuracy: 0.4072
# Epoch 25/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.7131 - accuracy: 0.5180 - val_loss: 2.2365 - val_accuracy: 0.3992
# Epoch 26/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.7063 - accuracy: 0.5145 - val_loss: 2.2969 - val_accuracy: 0.3822
# Epoch 27/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.6626 - accuracy: 0.5327 - val_loss: 2.2668 - val_accuracy: 0.3942
# Epoch 28/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.6274 - accuracy: 0.5344 - val_loss: 2.2026 - val_accuracy: 0.4052
# Epoch 29/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.5706 - accuracy: 0.5419 - val_loss: 2.2441 - val_accuracy: 0.4251
# Epoch 30/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.5467 - accuracy: 0.5579 - val_loss: 2.0626 - val_accuracy: 0.4521
# Epoch 31/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.4963 - accuracy: 0.5768 - val_loss: 2.0981 - val_accuracy: 0.4371
# Epoch 32/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.4866 - accuracy: 0.5714 - val_loss: 2.0984 - val_accuracy: 0.4341
# Epoch 33/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.4299 - accuracy: 0.5948 - val_loss: 2.0863 - val_accuracy: 0.4371
# Epoch 34/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.4137 - accuracy: 0.5936 - val_loss: 2.0607 - val_accuracy: 0.4581
# Epoch 35/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.3666 - accuracy: 0.6110 - val_loss: 2.1207 - val_accuracy: 0.4541
# Epoch 36/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.3674 - accuracy: 0.6020 - val_loss: 2.2464 - val_accuracy: 0.4381
# Epoch 37/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.3564 - accuracy: 0.6100 - val_loss: 2.0411 - val_accuracy: 0.4631
# Epoch 38/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 1.3352 - accuracy: 0.6138 - val_loss: 2.0500 - val_accuracy: 0.4551
# Epoch 39/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.2719 - accuracy: 0.6240 - val_loss: 1.9946 - val_accuracy: 0.4780
# Epoch 40/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.2706 - accuracy: 0.6307 - val_loss: 1.9680 - val_accuracy: 0.4860
# Epoch 41/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.2218 - accuracy: 0.6430 - val_loss: 2.1146 - val_accuracy: 0.4671
# Epoch 42/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.2436 - accuracy: 0.6357 - val_loss: 1.8780 - val_accuracy: 0.4940
# Epoch 43/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.1999 - accuracy: 0.6495 - val_loss: 2.0092 - val_accuracy: 0.4920
# Epoch 44/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.1801 - accuracy: 0.6587 - val_loss: 2.0780 - val_accuracy: 0.4551
# Epoch 45/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.1550 - accuracy: 0.6679 - val_loss: 2.0624 - val_accuracy: 0.4741
# Epoch 46/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.1513 - accuracy: 0.6694 - val_loss: 1.9684 - val_accuracy: 0.4960
# Epoch 47/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 1.1119 - accuracy: 0.6786 - val_loss: 1.9667 - val_accuracy: 0.5160
# Epoch 48/70
# 1002/1002 [==============================] - 23s 22ms/step - loss: 1.1019 - accuracy: 0.6679 - val_loss: 1.9332 - val_accuracy: 0.5090
# Epoch 49/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 1.0870 - accuracy: 0.6874 - val_loss: 1.9124 - val_accuracy: 0.5180
# Epoch 50/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 1.1164 - accuracy: 0.6737 - val_loss: 1.9191 - val_accuracy: 0.5030
# Epoch 51/70
# 1002/1002 [==============================] - 23s 22ms/step - loss: 1.0712 - accuracy: 0.6759 - val_loss: 2.0906 - val_accuracy: 0.4721
# Epoch 52/70
# 1002/1002 [==============================] - 23s 22ms/step - loss: 1.0209 - accuracy: 0.6989 - val_loss: 1.9773 - val_accuracy: 0.5120
# Epoch 53/70
# 1002/1002 [==============================] - 23s 22ms/step - loss: 1.0434 - accuracy: 0.6859 - val_loss: 2.0651 - val_accuracy: 0.4880
# Epoch 54/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.0145 - accuracy: 0.6999 - val_loss: 1.8397 - val_accuracy: 0.5250
# Epoch 55/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 1.0227 - accuracy: 0.6999 - val_loss: 1.9018 - val_accuracy: 0.5160
# Epoch 56/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9936 - accuracy: 0.7133 - val_loss: 1.9076 - val_accuracy: 0.5180
# Epoch 57/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9835 - accuracy: 0.7093 - val_loss: 1.8787 - val_accuracy: 0.5269
# Epoch 58/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9663 - accuracy: 0.7153 - val_loss: 1.9594 - val_accuracy: 0.5100
# Epoch 59/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9668 - accuracy: 0.7106 - val_loss: 2.0343 - val_accuracy: 0.4940
# Epoch 60/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9569 - accuracy: 0.7128 - val_loss: 1.9429 - val_accuracy: 0.5170
# Epoch 61/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9294 - accuracy: 0.7255 - val_loss: 1.9594 - val_accuracy: 0.5070
# Epoch 62/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.9149 - accuracy: 0.7353 - val_loss: 1.9706 - val_accuracy: 0.5020
# Epoch 63/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.9075 - accuracy: 0.7315 - val_loss: 1.7914 - val_accuracy: 0.5539
# Epoch 64/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.9096 - accuracy: 0.7246 - val_loss: 1.8729 - val_accuracy: 0.5429
# Epoch 65/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.8754 - accuracy: 0.7378 - val_loss: 2.0202 - val_accuracy: 0.5060
# Epoch 66/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.8818 - accuracy: 0.7403 - val_loss: 1.7814 - val_accuracy: 0.5519
# Epoch 67/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.8674 - accuracy: 0.7430 - val_loss: 1.8919 - val_accuracy: 0.5289
# Epoch 68/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.8778 - accuracy: 0.7408 - val_loss: 2.0135 - val_accuracy: 0.5180
# Epoch 69/70
# 1002/1002 [==============================] - 22s 22ms/step - loss: 0.8528 - accuracy: 0.7408 - val_loss: 1.8315 - val_accuracy: 0.5709
# Epoch 70/70
# 1002/1002 [==============================] - 23s 23ms/step - loss: 0.8784 - accuracy: 0.7458 - val_loss: 1.9327 - val_accuracy: 0.5240
# CPU times: user 1h 28min 32s, sys: 7min 15s, total: 1h 35min 48s
# Wall time: 26min 12s

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Evaluating the trained Model</font>**
#
# As done for the previous one, we will evaluate the `LRCN` model on the test set.

# %%
# %%time
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 53/53 [==============================] - 1s 14ms/step - loss: 1.3223 - accuracy: 0.6966

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Save the Model</font>**
#
# After that, we will save the model for future uses using the same technique we had used for the previous model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.3: Plot Model’s Loss & Accuracy Curves</font>**
#
# Now we will utilize the function **`plot_metric()`** we had created above to visualize the training and validation metrics of this model.

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
pred_LRCN = LRCN_model.predict(features_test)

# %%
gc.collect()
# Out:
# 88

# %%
pred_classes_LRCN = np.argmax(pred_LRCN, axis = 1)
pred_classes_LRCN;

# %%
y_label= np.argmax(labels_test, axis =1)

# %%
labels_test

# %%
plot_confusion_matrix_labeled(y_label,pred_classes_LRCN)

# %%
print_validation_report(y_label,pred_classes_LRCN)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        42
#            1       0.40      0.36      0.38        33
#            2       0.73      0.71      0.72        38
#            3       0.70      0.21      0.32        34
#            4       0.97      0.97      0.97        33
#            5       0.85      0.94      0.89        18
#            6       0.38      0.74      0.50        27
#            7       0.74      0.86      0.79        36
#            8       0.53      0.72      0.61        40
#            9       0.48      0.44      0.46        32
#           10       0.49      0.45      0.47        38
#           11       0.87      0.56      0.68        36
#           12       0.43      0.79      0.56        38
#           13       0.42      0.53      0.47        38
#           14       0.65      0.43      0.52        30
#           15       0.33      0.32      0.33        31
#           16       0.70      0.91      0.79        23
#           17       0.88      0.71      0.78        41
#           18       0.70      0.68      0.69        38
#           19       0.47      0.25      0.33        36
#           20       0.56      0.47      0.51        38
#           21       0.35      0.37      0.36        38
#           22       0.53      0.79      0.63        38
#           23       0.75      0.51      0.61        41
#           24       0.30      0.13      0.18        23
#           25       0.77      0.71      0.74        38
#           26       0.61      0.46      0.52        24
#           27       0.47      0.59      0.52        37
#           28       0.54      0.62      0.58        24
#           29       0.77      0.48      0.59        42
#           30       0.38      0.64      0.48        25
#           31       0.37      0.46      0.41        35
#           32       0.62      0.67      0.64        27
#           33       0.62      0.39      0.48        33
#           34       0.24      0.50      0.32        40
#           35       0.65      0.33      0.44        39
#           36       0.28      0.69      0.40        29
#           37       0.77      0.68      0.72        34
#           38       0.67      0.13      0.22        30
#           39       0.60      0.55      0.57        33
#           40       0.60      0.45      0.52        33
#           41       0.48      0.31      0.37        36
#           42       0.60      0.23      0.33        26
#           43       0.50      0.54      0.52        26
#           44       0.69      0.63      0.66        49
#           45       0.57      0.34      0.43        38
#           46       0.68      0.48      0.57        27
#           47       0.25      0.62      0.35        29
#           48       0.40      0.19      0.26        31
#           49       0.83      0.58      0.68        26
#
#     accuracy                           0.54      1671
#    macro avg       0.58      0.54      0.53      1671
# weighted avg       0.58      0.54      0.53      1671
#
# Accuracy Score: 0.5368043087971275
# Root Mean Square Error: 13.803116760934047

# %%
print_validation_report_labeled(y_label,pred_classes_LRCN)
# Out:
# Classification Report
#                     precision    recall  f1-score   support
#
#      BaseballPitch       0.69      0.69      0.69        42
#         Basketball       0.40      0.36      0.38        33
#         BenchPress       0.73      0.71      0.72        38
#             Biking       0.70      0.21      0.32        34
#          Billiards       0.97      0.97      0.97        33
#       BreastStroke       0.85      0.94      0.89        18
#       CleanAndJerk       0.38      0.74      0.50        27
#             Diving       0.74      0.86      0.79        36
#           Drumming       0.53      0.72      0.61        40
#            Fencing       0.48      0.44      0.46        32
#          GolfSwing       0.49      0.45      0.47        38
#           HighJump       0.87      0.56      0.68        36
#          HorseRace       0.43      0.79      0.56        38
#        HorseRiding       0.42      0.53      0.47        38
#           HulaHoop       0.65      0.43      0.52        30
#       JavelinThrow       0.33      0.32      0.33        31
#      JugglingBalls       0.70      0.91      0.79        23
#           JumpRope       0.88      0.71      0.78        41
#        JumpingJack       0.70      0.68      0.69        38
#           Kayaking       0.47      0.25      0.33        36
#             Lunges       0.56      0.47      0.51        38
#     MilitaryParade       0.35      0.37      0.36        38
#             Mixing       0.53      0.79      0.63        38
#          Nunchucks       0.75      0.51      0.61        41
#       PizzaTossing       0.30      0.13      0.18        23
#      PlayingGuitar       0.77      0.71      0.74        38
#       PlayingPiano       0.61      0.46      0.52        24
#       PlayingTabla       0.47      0.59      0.52        37
#      PlayingViolin       0.54      0.62      0.58        24
#          PoleVault       0.77      0.48      0.59        42
#        PommelHorse       0.38      0.64      0.48        25
#            PullUps       0.37      0.46      0.41        35
#              Punch       0.62      0.67      0.64        27
#            PushUps       0.62      0.39      0.48        33
# RockClimbingIndoor       0.24      0.50      0.32        40
#       RopeClimbing       0.65      0.33      0.44        39
#             Rowing       0.28      0.69      0.40        29
#          SalsaSpin       0.77      0.68      0.72        34
#      SkateBoarding       0.67      0.13      0.22        30
#             Skiing       0.60      0.55      0.57        33
#             Skijet       0.60      0.45      0.52        33
#     SoccerJuggling       0.48      0.31      0.37        36
#              Swing       0.60      0.23      0.33        26
#             TaiChi       0.50      0.54      0.52        26
#        TennisSwing       0.69      0.63      0.66        49
#        ThrowDiscus       0.57      0.34      0.43        38
#  TrampolineJumping       0.68      0.48      0.57        27
#  VolleyballSpiking       0.25      0.62      0.35        29
#     WalkingWithDog       0.40      0.19      0.26        31
#               YoYo       0.83      0.58      0.68        26
#
#           accuracy                           0.54      1671
#          macro avg       0.58      0.54      0.53      1671
#       weighted avg       0.58      0.54      0.53      1671
#
# Accuracy Score: 0.5368043087971275
# Root Mean Square Error: 13.803116760934047

# %% [markdown]
# ** Visualize the Data with its Labels for LCRN model**

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = y_label

# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 20)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = list(pred_classes_LRCN)

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    #video_reader = cv2.VideoCapture(features_test[random_index])
    
    # Read the first frame of the video file.
    #_, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    #video_reader.release()
    rgb_frame = cv2_imshow(features_test[random_index][4])

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8804C1BE90>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-121-dcb73d394c1b> in <module>()
#      32
#      33     # Convert the frame from BGR into RGB format.
# ---> 34     rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
#      35
#      36     # Write the class name on the video frame.
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
rgb_frame = cv2_imshow(features_test[random_index])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-ab59f37b2160> in <module>()
# ----> 1 video_reader =cv2.VideoCapture(features_test[2])
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
  _, bgr_frame = video_reader.read()

# %%
type(video_reader)
# Out:
# cv2.VideoCapture

# %%
# !pip install -q imageio
# !pip install -q opencv-python
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
# Some modules to display an animation using imageio.
import imageio
from IPython import display
from tensorflow_docs.vis import embed

# %%
def to_gif(images):
    plt.figure(figsize=(50,50))
    converted_images = images.astype(np.uint8)
    imageio.mimsave("animation.gif", converted_images, fps=5)
    return embed.embed_file("animation.gif")

# %%
from google.colab.patches import cv2_imshow

# %%
image = features[0]*255
 
to_gif(image[:20])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
pred_classes_LRCN[4]
# Out:
# 17

# %%
y_label[4]
# Out:
# 42

# %%
image = features_test[4]*255
 
to_gif(image[:20])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
CLASSES_LIST[17]
# Out:
# 'RockClimbingIndoor'

# %%
   with open('/content/gdrive/MyDrive/classes.txt') as f:
    lines = f.readlines()

# %%
CLASSES_LIST =[]
for i in lines:
  i = i.replace(" ",'')
  i= i.replace("\n","")
  CLASSES_LIST.append(i)

# %%
for i in range(len(pred_classes_LRCN)):
  if pred_classes_LRCN[i] != y_label[i]:
    print (i)
