# %%
import pandas as pd

group  = ['LSTM', 'LSTM','LSTM','LSTM', 
       'LSTM', 'LSTM','LSTM','LSTM',
       'LSTM', 'LSTM','LSTM','LSTM',
       
       'RNN', 'RNN','RNN','RNN',
       'RNN', 'RNN','RNN','RNN',
       'RNN', 'RNN','RNN','RNN',
       
       'CNN', 'CNN', 'CNN',
        'LSTM', 'LSTM','LSTM', 'LSTM',
         'RNN', 'RNN'
        
       ]

model = ['Model 1A', ' Model 1B', 'Model 1C', ' Model 1D', 
         'Model 1AA', ' Model 1BB', 'Model 1CC', ' Model 1DD',
         'Model 1AAA', ' Model 1BBB', 'Model 1CCC', ' Model 1DDD',
         
         'Model 2A', 'Model 2B', 'Model 2C', 'Model 2D', 
         'Model 2AA', 'Model 2BB', 'Model 2CC', 'Model 2DD', 
         'Model 2AAA', 'Model 2BBB', 'Model 2CCC', 'Model 2DD', 
         
         'Model 3A', 'Model 3B', 'Model 3C',
         
          'Model 4A', 'Model 4B', 'Model 4C', 'Model 4D',
         
         'Model 5A', 'Model 5B']
         
       
output_seq = ['Defualt', 'Defualt','Defualt', 'Default',
             'Defualt', 'Defualt','Defualt', 'Default',
             'Defualt', 'Defualt','Defualt', 'Default',
             'Defualt', 'Defualt','Defualt', 'Default',
              
             'Defualt', 'Defualt','Defualt', 'Default',
             'Defualt', 'Defualt','Defualt', 'Default',
             '40', '40','60', 
             '60', '60','40', '60',
              '40',
              '40'
             ]

architecture  = ["1 Layer LSTM _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer LSTM _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                "1 Layer LSTM _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer LSTM _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                 "1 Layer LSTM _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer LSTM _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer LSTM _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                "1 Layer RNN _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer RNN _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                     "1 Layer RNN _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer RNN _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                     "1 Layer RNN _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
               " 1 Layer RNN _Unidirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
               " 2 Layer RNN _Unidirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes",
                
                ' 1 layer CON1d 64 Kernel, MaxPool1D, \n  3, 1 Dense layer 64 Nodes',
                " 3 Layer CON1d 64 + 128 + 256 Kernel , MaxPool1D,\n  2 Dense layer 256 + 256 Nodes",
                  ' 1 layer CON1d 64 Kernel, MaxPool1D, \n  3, 1 Dense layer 64 Nodes',
                
                "1 Layer LSTM _BIdirectional 128 Cells \n + 1 Dense Layer 128 Nodes",
                "1 Layer LSTM _BIdirectional 128 Cells \n + 1 Dense Layer 128 Nodes",
                "1 Layer LSTM _BIdirectional 64 + 32 Cells \n + 1 Dense Layer 128 Nodes",
                "1 Layer LSTM _BIdirectional 128 Cells \n + 1 Dense Layer 128 Nodes",
                 
                "1 Layer RNN _BIdirectional 64 Cells \n + 1 Dense Layer 64 Nodes ",
                " 2 Layer RNN _BIdirectional 64 + 32  Cells \n + 1 Dense Layer 64 Nodes"
               ]


vocabulary_size = ['1000', '1000' , '1000', '1000', 
                  '2000', '2000' , '2000', '2000',
                  '3000', '3000','3000','3000',
                   '1000', '1000' , '1000', '1000', 
                  '2000', '2000' , '2000', '2000',
                  '3000', '3000','3000','3000',
                   '3000', '3000', 'Max',
                   '1000',
                   '3000',
                   '3000',
                   'Max',
                   '3000',
                   '3000']
                   
                
                  
                  

optimizer = ['ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM', 'ADAM', 'ADAM', 'ADAM',
             'ADAM',
             'ADAM',
              'ADAM','ADAM', 'ADAM']
             



regularization = ['Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                 'Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                  'Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                  'Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                 'Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                  'Early stopping', "Early stopping + Dropout", 'Early stopping', "Early stopping + Dropout",
                  
                   'Early stopping', "Early stopping + Dropout","Early stopping + Dropout"
                  
                   "Early stopping + Dropout",
                   "Early stopping + Dropout",
                  "Early stopping + Dropout",
                  "Early stopping + Dropout",
                  
                  "Early stopping + Dropout",
                  "Early stopping + Dropout",]
                  
                  


train = [86.36 , 85.61, 86.11, 84.77, 
         88.59, 88.54, 85.31,  83.30,
        90.02, 89.03, 90.19, 83.62,
        86.26, 84.29, 86.38, 81.50, 
        87.90, 87.17 , 88.92, 86.13,
        90.81, 90.08, 90.59, 79.21,
        89.91, 90.43,94.25,
         87.38, 86.07, 92.46,8.29,
        90.26, 81.71
         ]


valid = [ 86.55, 87.03, 86.05, 86.35, 
         88.07, 88.85, 85.47, 88.96,
         88.90, 89.12, 88.97, 89.48,
         86.30, 86.15, 85.92, 84.01,
         89.16 , 86.98 , 87.80, 87.50,
        88.75, 88.02, 88.72, 86.98,
        89.15, 88.75, 91.08,
         87.0,  89.38,  90.42, 92.60,
        88.78, 88.23
        ]



test = [ 85.34, 85.69, 84.96, 85.03,
       87.69, 87.29, 84.64, 87.43,
       88.64, 88.71 ,88.44, 88.05,
       85.22,  83.61, 84.40, 81.74,
       87.54, 85.92, 87.17 , 85.20,
       88.39, 86.78 , 87.91, 86.96,
       88.83, 87.81 , 90.68,
        88.36,  88.86, 88.52, 89.63,
       87.10, 87.60
       ]



time = ['4 min 9 s', "3 min 16 s", "5 min 19s", "6 min 3 s",
       '18 min 42 s', '23 min 29 s', ' 6 min 12 s', '10 min 23 s',
       '4 min 27 s', '4 min 0 s', ' 3 min 24 s', '2 min 12s',
       '9 min 55 s', '7 min 7 s', '9 min 17 s', ' 10 min 2 s',
       '42 min 32 s', '37 min 17 s', ' 26 min 43 s', '22 min 5 s',
       '36 min 17 s', '25 min 42 s', ' 16 min 28 s', ' 7 min 2 s',
       '4 min 42 s', '16 min 12s','1 min 37s',
      
       '5 min 4 s',
        '12 min 38s',
       '11 min 50 s',
        '3 min 2 S',
        
       '8 min 25 s',
        '21 min 8 s']

# %%
df = pd.DataFrame([group, model, architecture,vocabulary_size, output_seq, regularization, train, valid,test, time ])

df= df.T

# %%
df.columns = ['Type', 'Name','Architecture','Vocabulary Size',"Output Sequence len", "Regularization", 'Train Accuracy',  'Valid Accuracy', 'Test Accuracy','Time']

df = df.set_index('Name')

# %%
from tabulate import tabulate

#print(tabulate(df, headers='keys', tablefmt='fancy_grid'))

# %%
df1 = df.sort_values('Test Accuracy', ascending=  False)

# %%
from IPython.display import display, HTML

print ("Dataframe:")
display(HTML(df.to_html().replace("\\n","<br>")))
# Out:
# Dataframe:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Architecture</th>
#       <th>Vocabulary Size</th>
#       <th>Output Sequence len</th>
#       <th>Regularization</th>
#       <th>Train Accuracy</th>
#       <th>Valid Accuracy</th>
#       <th>Test Accuracy</th>
#       <th>Time</th>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Model 1A</th>
#       <td>LSTM</td>
#       <td>1 Layer LSTM _BIdirectional 64 Cells <br> + 1 Dense Layer 64 Nodes</td>
#       <td>1000</td>
#       <td>Defualt</td>
#       <td>Early stopping</td>
#       <td>86.36</td>
#       <td>86.55</td>
#       <td>85.34</td>
#       <td>4 min 9 s</td>
#     </tr>
#     <tr>
# ...

# %%
from IPython.display import display, HTML

print ("Dataframe:")
display(HTML(df1.head(10).to_html().replace("\\n","<br>")))
# Out:
# Dataframe:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Architecture</th>
#       <th>Vocabulary Size</th>
#       <th>Output Sequence len</th>
#       <th>Regularization</th>
#       <th>Train Accuracy</th>
#       <th>Valid Accuracy</th>
#       <th>Test Accuracy</th>
#       <th>Time</th>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Model 3C</th>
#       <td>CNN</td>
#       <td>1 layer CON1d 64 Kernel, MaxPool1D, <br>  3, 1 Dense layer 64 Nodes</td>
#       <td>Max</td>
#       <td>60</td>
#       <td>Early stopping + DropoutEarly stopping + Dropout</td>
#       <td>94.25</td>
#       <td>91.08</td>
#       <td>90.68</td>
#       <td>1 min 37s</td>
#     </tr>
# ...

# %%
from tabulate import tabulate

print(tabulate(df1.head(1), headers='keys', tablefmt='fancy_grid'))
# Out:
# ╒══════════╤════════╤══════════════════════════════════════╤═══════════════════╤═══════════════════════╤══════════════════════════════════════════════════╤══════════════════╤══════════════════╤═════════════════╤═══════════╕
# │ Name     │ Type   │ Architecture                         │ Vocabulary Size   │   Output Sequence len │ Regularization                                   │   Train Accuracy │   Valid Accuracy │   Test Accuracy │ Time      │
# ╞══════════╪════════╪══════════════════════════════════════╪═══════════════════╪═══════════════════════╪══════════════════════════════════════════════════╪══════════════════╪══════════════════╪═════════════════╪═══════════╡
# │ Model 3C │ CNN    │ 1 layer CON1d 64 Kernel, MaxPool1D,  │ Max               │                    60 │ Early stopping + DropoutEarly stopping + Dropout │            94.25 │            91.08 │           90.68 │ 1 min 37s │
# ...
